# %%
#required
import chess
import chess.pgn
import re
import math
import os #for os.path.basename() only 

#source code
import sys
sys.path.append('../src')
import chessposition
import parsepgn
import databaseprune
import analysisbasic
import display

import lightdb


# import specific methods
from chessposition import *
from parsepgn import *
from databaseprune import *
from analysisbasic import *
from display import *

# overview of the functions that are really used
from lightdb import LightDatabase

# %% [markdown]
# ## Read parsed databases

# %%
print("--------eco")
# %time %store -r light_w_c25_all_20
# %time %store -r light_b_c25_all_20

print("--------few elite")
# %time %store -r light_w_elite_100_10
# %time %store -r light_b_elite_100_10

# %time %store -r light_w_elite_1000_10
# %time %store -r light_b_elite_1000_10

# %time %store -r light_w_elite_10000_10
# %time %store -r light_b_elite_10000_10


print("-------enriched")

# %time %store -r light_w_elite_1000_6_20000
# %time %store -r light_b_elite_1000_6_20000

# %time %store -r light_w_elite_1000_10_20000
# %time %store -r light_b_elite_1000_10_20000

# %time %store -r light_w_elite_10000_12_20000
# %time %store -r light_b_elite_10000_12_20000

# %time %store -r light_w_elite_1000_10_300000
# %time %store -r light_b_elite_1000_10_300000

print("--------trim20")


# %time %store -r light_w_elite_1000_6_20000_t20
# %time %store -r light_b_elite_1000_6_20000_t20

# %time %store -r light_w_elite_1000_10_20000_t20
# %time %store -r light_b_elite_1000_10_20000_t20

# %time %store -r light_w_elite_10000_12_20000_t20
# %time %store -r light_b_elite_10000_12_20000_t20

# %time %store -r light_w_elite_1000_10_300000_t20
# %time %store -r light_b_elite_1000_10_300000_t20

print("--------trim100")


# %time %store -r light_w_elite_1000_6_20000_t100
# %time %store -r light_b_elite_1000_6_20000_t100

# %time %store -r light_w_elite_1000_10_20000_t100
# %time %store -r light_b_elite_1000_10_20000_t100

# %time %store -r light_w_elite_10000_12_20000_t100
# %time %store -r light_b_elite_10000_12_20000_t100

# %time %store -r light_w_elite_1000_10_300000_t100
# %time %store -r light_b_elite_1000_10_300000_t100
# Out:
# --------eco
# Wall time: 120 ms
# Wall time: 130 ms
# --------few elite
# Wall time: 10 ms
# Wall time: 6 ms
# Wall time: 53 ms
# Wall time: 116 ms
# Wall time: 413 ms
# Wall time: 530 ms
# -------enriched
# Wall time: 26 ms
# Wall time: 24 ms
# Wall time: 51 ms
# Wall time: 72.9 ms
# Wall time: 1 s
# Wall time: 708 ms
# Wall time: 505 ms
# Wall time: 47 ms
# --------trim20
# Wall time: 5.33 ms
# Wall time: 6.21 ms
# Wall time: 6.02 ms
# Wall time: 6.96 ms
# Wall time: 11.2 ms
# Wall time: 11 ms
# Wall time: 14.5 ms
# Wall time: 15.4 ms
# --------trim100
# Wall time: 2.36 ms
# Wall time: 3.24 ms
# Wall time: 3.09 ms
# Wall time: 3 ms
# Wall time: 4 ms
# Wall time: 2.68 ms
# Wall time: 8.13 ms
# Wall time: 7.99 ms

# %%
print("--------eco")
# %time alight_w_c25_all_20=deepcopy(light_w_c25_all_20)
# %time alight_b_c25_all_20=deepcopy(light_w_c25_all_20)

print("--------few elite")
# %time alight_w_elite_100_10=deepcopy(light_w_elite_100_10)
# %time alight_b_elite_100_10=deepcopy(light_b_elite_100_10)

# %time alight_w_elite_1000_10=deepcopy(light_w_elite_1000_10)
# %time alight_b_elite_1000_10=deepcopy(light_b_elite_1000_10)

# %time alight_w_elite_10000_10=deepcopy(light_w_elite_10000_10)
# %time alight_b_elite_10000_10=deepcopy(light_b_elite_10000_10)


print("-------enriched")

# %time alight_w_elite_1000_6_20000=deepcopy(light_w_elite_1000_6_20000)
# %time alight_b_elite_1000_6_20000=deepcopy(light_b_elite_1000_6_20000)

# %time alight_w_elite_1000_10_20000=deepcopy(light_w_elite_1000_10_20000)
# %time alight_b_elite_1000_10_20000=deepcopy(light_b_elite_1000_10_20000)

# %time alight_w_elite_10000_12_20000=deepcopy(light_w_elite_10000_12_20000)
# %time alight_b_elite_10000_12_20000=deepcopy(light_b_elite_10000_12_20000)

# %time alight_w_elite_1000_10_300000=deepcopy(light_w_elite_1000_10_300000)
# %time alight_b_elite_1000_10_300000=deepcopy(light_b_elite_1000_10_300000)

print("--------trim20")


# %time alight_w_elite_1000_6_20000_t20=deepcopy(light_w_elite_1000_6_20000_t20)
# %time alight_b_elite_1000_6_20000_t20=deepcopy(light_b_elite_1000_6_20000_t20)

# %time alight_w_elite_1000_10_20000_t20=deepcopy(light_w_elite_1000_10_20000_t20)
# %time alight_b_elite_1000_10_20000_t20=deepcopy(light_b_elite_1000_10_20000_t20)

# %time alight_w_elite_10000_12_20000_t20=deepcopy(light_w_elite_10000_12_20000_t20)
# %time alight_b_elite_10000_12_20000_t20=deepcopy(light_b_elite_10000_12_20000_t20)

# %time alight_w_elite_1000_10_300000_t20=deepcopy(light_w_elite_1000_10_300000_t20)
# %time alight_b_elite_1000_10_300000_t20=deepcopy(light_b_elite_1000_10_300000_t20)

print("--------trim100")

# %time alight_w_elite_1000_6_20000_t100=deepcopy(light_w_elite_1000_6_20000_t100)
# %time alight_b_elite_1000_6_20000_t100=deepcopy(light_b_elite_1000_6_20000_t100)

# %time alight_w_elite_1000_10_20000_t100=deepcopy(light_w_elite_1000_10_20000_t100)
# %time alight_b_elite_1000_10_20000_t100=deepcopy(light_b_elite_1000_10_20000_t100)

# %time alight_w_elite_10000_12_20000_t100=deepcopy(light_w_elite_10000_12_20000_t100)
# %time alight_b_elite_10000_12_20000_t100=deepcopy(light_b_elite_10000_12_20000_t100)

# %time alight_w_elite_1000_10_300000_t100=deepcopy(light_w_elite_1000_10_300000_t100)
# %time alight_b_elite_1000_10_300000_t100=deepcopy(light_b_elite_1000_10_300000_t100)
# Out:
# --------eco
# Wall time: 498 ms
# Wall time: 1.26 s
# --------few elite
# Wall time: 30 ms
# Wall time: 39 ms
# Wall time: 296 ms
# Wall time: 292 ms
# Wall time: 1.72 s
# Wall time: 2.24 s
# -------enriched
# Wall time: 74 ms
# Wall time: 76.9 ms
# Wall time: 213 ms
# Wall time: 216 ms
# Wall time: 3.55 s
# Wall time: 2.68 s
# Wall time: 1.18 s
# Wall time: 248 ms
# --------trim20
# Wall time: 22 ms
# Wall time: 28 ms
# Wall time: 40 ms
# Wall time: 39 ms
# Wall time: 65 ms
# Wall time: 81.9 ms
# Wall time: 108 ms
# Wall time: 108 ms
# --------trim100
# Wall time: 6.99 ms
# Wall time: 7 ms
# Wall time: 7 ms
# Wall time: 8.99 ms
# Wall time: 11 ms
# Wall time: 14 ms
# Wall time: 51 ms
# Wall time: 55 ms

# %%
print("--------eco")
# %time a52light_w_c25_all_20=deepcopy(light_w_c25_all_20)
# %time a52light_b_c25_all_20=deepcopy(light_w_c25_all_20)

print("--------few elite")
# %time a52light_w_elite_100_10=deepcopy(light_w_elite_100_10)
# %time a52light_b_elite_100_10=deepcopy(light_b_elite_100_10)

# %time a52light_w_elite_1000_10=deepcopy(light_w_elite_1000_10)
# %time a52light_b_elite_1000_10=deepcopy(light_b_elite_1000_10)

# %time a52light_w_elite_10000_10=deepcopy(light_w_elite_10000_10)
# %time a52light_b_elite_10000_10=deepcopy(light_b_elite_10000_10)


print("-------enriched")

# %time a52light_w_elite_1000_6_20000=deepcopy(light_w_elite_1000_6_20000)
# %time a52light_b_elite_1000_6_20000=deepcopy(light_b_elite_1000_6_20000)

# %time a52light_w_elite_1000_10_20000=deepcopy(light_w_elite_1000_10_20000)
# %time a52light_b_elite_1000_10_20000=deepcopy(light_b_elite_1000_10_20000)

# %time a52light_w_elite_10000_12_20000=deepcopy(light_w_elite_10000_12_20000)
# %time a52light_b_elite_10000_12_20000=deepcopy(light_b_elite_10000_12_20000)

# %time a52light_w_elite_1000_10_300000=deepcopy(light_w_elite_1000_10_300000)
# %time a52light_b_elite_1000_10_300000=deepcopy(light_b_elite_1000_10_300000)

print("--------trim20")


# %time a52light_w_elite_1000_6_20000_t20=deepcopy(light_w_elite_1000_6_20000_t20)
# %time a52light_b_elite_1000_6_20000_t20=deepcopy(light_b_elite_1000_6_20000_t20)

# %time a52light_w_elite_1000_10_20000_t20=deepcopy(light_w_elite_1000_10_20000_t20)
# %time a52light_b_elite_1000_10_20000_t20=deepcopy(light_b_elite_1000_10_20000_t20)

# %time a52light_w_elite_10000_12_20000_t20=deepcopy(light_w_elite_10000_12_20000_t20)
# %time a52light_b_elite_10000_12_20000_t20=deepcopy(light_b_elite_10000_12_20000_t20)

# %time a52light_w_elite_1000_10_300000_t20=deepcopy(light_w_elite_1000_10_300000_t20)
# %time a52light_b_elite_1000_10_300000_t20=deepcopy(light_b_elite_1000_10_300000_t20)

print("--------trim100")

# %time a52light_w_elite_1000_6_20000_t100=deepcopy(light_w_elite_1000_6_20000_t100)
# %time a52light_b_elite_1000_6_20000_t100=deepcopy(light_b_elite_1000_6_20000_t100)

# %time a52light_w_elite_1000_10_20000_t100=deepcopy(light_w_elite_1000_10_20000_t100)
# %time a52light_b_elite_1000_10_20000_t100=deepcopy(light_b_elite_1000_10_20000_t100)

# %time a52light_w_elite_10000_12_20000_t100=deepcopy(light_w_elite_10000_12_20000_t100)
# %time a52light_b_elite_10000_12_20000_t100=deepcopy(light_b_elite_10000_12_20000_t100)

# %time a52light_w_elite_1000_10_300000_t100=deepcopy(light_w_elite_1000_10_300000_t100)
# %time a52light_b_elite_1000_10_300000_t100=deepcopy(light_b_elite_1000_10_300000_t100)
# Out:
# --------eco
# Wall time: 502 ms
# Wall time: 625 ms
# --------few elite
# Wall time: 51 ms
# Wall time: 41 ms
# Wall time: 255 ms
# Wall time: 328 ms
# Wall time: 1.68 s
# Wall time: 2.7 s
# -------enriched
# Wall time: 77 ms
# Wall time: 72 ms
# Wall time: 218 ms
# Wall time: 217 ms
# Wall time: 2.03 s
# Wall time: 3.8 s
# Wall time: 217 ms
# Wall time: 230 ms
# --------trim20
# Wall time: 23 ms
# Wall time: 37 ms
# Wall time: 42 ms
# Wall time: 32 ms
# Wall time: 68 ms
# Wall time: 69 ms
# Wall time: 111 ms
# Wall time: 88.9 ms
# --------trim100
# Wall time: 6 ms
# Wall time: 6.02 ms
# Wall time: 7 ms
# Wall time: 7.02 ms
# Wall time: 11 ms
# Wall time: 11 ms
# Wall time: 57.9 ms
# Wall time: 58 ms

# %%
print("--------eco")
# %time a365light_w_c25_all_20=deepcopy(light_w_c25_all_20)
# %time a365light_b_c25_all_20=deepcopy(light_w_c25_all_20)

print("--------few elite")
# %time a365light_w_elite_100_10=deepcopy(light_w_elite_100_10)
# %time a365light_b_elite_100_10=deepcopy(light_b_elite_100_10)

# %time a365light_w_elite_1000_10=deepcopy(light_w_elite_1000_10)
# %time a365light_b_elite_1000_10=deepcopy(light_b_elite_1000_10)

# %time a365light_w_elite_10000_10=deepcopy(light_w_elite_10000_10)
# %time a365light_b_elite_10000_10=deepcopy(light_b_elite_10000_10)


print("-------enriched")

# %time a365light_w_elite_1000_6_20000=deepcopy(light_w_elite_1000_6_20000)
# %time a365light_b_elite_1000_6_20000=deepcopy(light_b_elite_1000_6_20000)

# %time a365light_w_elite_1000_10_20000=deepcopy(light_w_elite_1000_10_20000)
# %time a365light_b_elite_1000_10_20000=deepcopy(light_b_elite_1000_10_20000)

# %time a365light_w_elite_10000_12_20000=deepcopy(light_w_elite_10000_12_20000)
# %time a365light_b_elite_10000_12_20000=deepcopy(light_b_elite_10000_12_20000)

# %time a365light_w_elite_1000_10_300000=deepcopy(light_w_elite_1000_10_300000)
# %time a365light_b_elite_1000_10_300000=deepcopy(light_b_elite_1000_10_300000)

print("--------trim20")


# %time a365light_w_elite_1000_6_20000_t20=deepcopy(light_w_elite_1000_6_20000_t20)
# %time a365light_b_elite_1000_6_20000_t20=deepcopy(light_b_elite_1000_6_20000_t20)

# %time a365light_w_elite_1000_10_20000_t20=deepcopy(light_w_elite_1000_10_20000_t20)
# %time a365light_b_elite_1000_10_20000_t20=deepcopy(light_b_elite_1000_10_20000_t20)

# %time a365light_w_elite_10000_12_20000_t20=deepcopy(light_w_elite_10000_12_20000_t20)
# %time a365light_b_elite_10000_12_20000_t20=deepcopy(light_b_elite_10000_12_20000_t20)

# %time a365light_w_elite_1000_10_300000_t20=deepcopy(light_w_elite_1000_10_300000_t20)
# %time a365light_b_elite_1000_10_300000_t20=deepcopy(light_b_elite_1000_10_300000_t20)

print("--------trim100")

# %time a365light_w_elite_1000_6_20000_t100=deepcopy(light_w_elite_1000_6_20000_t100)
# %time a365light_b_elite_1000_6_20000_t100=deepcopy(light_b_elite_1000_6_20000_t100)

# %time a365light_w_elite_1000_10_20000_t100=deepcopy(light_w_elite_1000_10_20000_t100)
# %time a365light_b_elite_1000_10_20000_t100=deepcopy(light_b_elite_1000_10_20000_t100)

# %time a365light_w_elite_10000_12_20000_t100=deepcopy(light_w_elite_10000_12_20000_t100)
# %time a365light_b_elite_10000_12_20000_t100=deepcopy(light_b_elite_10000_12_20000_t100)

# %time a365light_w_elite_1000_10_300000_t100=deepcopy(light_w_elite_1000_10_300000_t100)
# %time a365light_b_elite_1000_10_300000_t100=deepcopy(light_b_elite_1000_10_300000_t100)
# Out:
# --------eco
# Wall time: 544 ms
# Wall time: 622 ms
# --------few elite
# Wall time: 38 ms
# Wall time: 35 ms
# Wall time: 237 ms
# Wall time: 227 ms
# Wall time: 1.38 s
# Wall time: 1.44 s
# -------enriched
# Wall time: 82 ms
# Wall time: 81 ms
# Wall time: 245 ms
# Wall time: 253 ms
# Wall time: 4.45 s
# Wall time: 2.24 s
# Wall time: 253 ms
# Wall time: 235 ms
# --------trim20
# Wall time: 24 ms
# Wall time: 23 ms
# Wall time: 35 ms
# Wall time: 35 ms
# Wall time: 83.9 ms
# Wall time: 82.9 ms
# Wall time: 106 ms
# Wall time: 117 ms
# --------trim100
# Wall time: 8.02 ms
# Wall time: 8 ms
# Wall time: 9.02 ms
# Wall time: 7 ms
# Wall time: 11 ms
# Wall time: 11 ms
# Wall time: 47.9 ms
# Wall time: 52 ms

# %% [markdown]
# ## Analyze!

# %%
print("--------eco")
# %time alight_w_c25_all_20.analyze(10)
# %time alight_b_c25_all_20.analyze(10)

print("--------few elite")
# %time alight_w_elite_100_10.analyze(10)
# %time alight_b_elite_100_10.analyze(10)

# %time alight_w_elite_1000_10.analyze(10)
# %time alight_b_elite_1000_10.analyze(10)

# %time alight_w_elite_10000_10.analyze(10)
# %time alight_b_elite_10000_10.analyze(10)


print("-------enriched")

# %time alight_w_elite_1000_6_20000.analyze(10)
# %time alight_b_elite_1000_6_20000.analyze(10)

# %time alight_w_elite_1000_10_20000.analyze(10)
# %time alight_b_elite_1000_10_20000.analyze(10)

# %time alight_w_elite_10000_12_20000.analyze(10)
# %time alight_b_elite_10000_12_20000.analyze(10)

# %time alight_w_elite_1000_10_300000.analyze(10)
# %time alight_b_elite_1000_10_300000.analyze(10)

print("--------trim20")


# %time alight_w_elite_1000_6_20000_t20.analyze(10)
# %time alight_b_elite_1000_6_20000_t20.analyze(10)

# %time alight_w_elite_1000_10_20000_t20.analyze(10)
# %time alight_b_elite_1000_10_20000_t20.analyze(10)

# %time alight_w_elite_10000_12_20000_t20.analyze(10)
# %time alight_b_elite_10000_12_20000_t20.analyze(10)

# %time alight_w_elite_1000_10_300000_t20.analyze(10)
# %time alight_b_elite_1000_10_300000_t20.analyze(10)

print("--------trim100")

# %time alight_w_elite_1000_6_20000_t100.analyze(10)
# %time alight_b_elite_1000_6_20000_t100.analyze(10)

# %time alight_w_elite_1000_10_20000_t100.analyze(10)
# %time alight_b_elite_1000_10_20000_t100.analyze(10)

# %time alight_w_elite_10000_12_20000_t100.analyze(10)
# %time alight_b_elite_10000_12_20000_t100.analyze(10)

# %time alight_w_elite_1000_10_300000_t100.analyze(10)
# %time alight_b_elite_1000_10_300000_t100.analyze(10)
# Out:
# --------eco
# Wall time: 109 ms
# Wall time: 126 ms
# --------few elite
# Wall time: 11 ms
# Wall time: 10 ms
# Wall time: 44 ms
# Wall time: 52 ms
# Wall time: 241 ms
# Wall time: 371 ms
# -------enriched
# Wall time: 11 ms
# Wall time: 18 ms
# Wall time: 72 ms
# Wall time: 80 ms
# Wall time: 561 ms
# Wall time: 538 ms
# Wall time: 39 ms
# Wall time: 55 ms
# --------trim20
# Wall time: 4 ms
# Wall time: 6 ms
# Wall time: 7.99 ms
# Wall time: 9.99 ms
# Wall time: 18 ms
# Wall time: 20 ms
# Wall time: 23 ms
# Wall time: 35 ms
# --------trim100
# Wall time: 2 ms
# Wall time: 2 ms
# Wall time: 2 ms
# Wall time: 998 µs
# Wall time: 2 ms
# Wall time: 4 ms
# Wall time: 16 ms
# Wall time: 16 ms

# %%
print("--------eco")
# %time %store alight_w_c25_all_20
# %time %store alight_b_c25_all_20

print("--------few elite")
# %time %store alight_w_elite_100_10
# %time %store alight_b_elite_100_10

# %time %store alight_w_elite_1000_10
# %time %store alight_b_elite_1000_10

# %time %store alight_w_elite_10000_10
# %time %store alight_b_elite_10000_10


print("-------enriched")

# %time %store alight_w_elite_1000_6_20000
# %time %store alight_b_elite_1000_6_20000

# %time %store alight_w_elite_1000_10_20000
# %time %store alight_b_elite_1000_10_20000

# %time %store alight_w_elite_10000_12_20000
# %time %store alight_b_elite_10000_12_20000

# %time %store alight_w_elite_1000_10_300000
# %time %store alight_b_elite_1000_10_300000

print("--------trim20")


# %time %store alight_w_elite_1000_6_20000_t20
# %time %store alight_b_elite_1000_6_20000_t20

# %time %store alight_w_elite_1000_10_20000_t20
# %time %store alight_b_elite_1000_10_20000_t20

# %time %store alight_w_elite_10000_12_20000_t20
# %time %store alight_b_elite_10000_12_20000_t20

# %time %store alight_w_elite_1000_10_300000_t20
# %time %store alight_b_elite_1000_10_300000_t20

print("--------trim100")

# %time %store alight_w_elite_1000_6_20000_t100
# %time %store alight_b_elite_1000_6_20000_t100

# %time %store alight_w_elite_1000_10_20000_t100
# %time %store alight_b_elite_1000_10_20000_t100

# %time %store alight_w_elite_10000_12_20000_t100
# %time %store alight_b_elite_10000_12_20000_t100

# %time %store alight_w_elite_1000_10_300000_t100
# %time %store alight_b_elite_1000_10_300000_t100
# Out:
# --------eco
# Stored 'alight_w_c25_all_20' (LightDatabase)
# Wall time: 76.9 ms
# Stored 'alight_b_c25_all_20' (LightDatabase)
# Wall time: 71.9 ms
# --------few elite
# Stored 'alight_w_elite_100_10' (LightDatabase)
# Wall time: 7.53 ms
# Stored 'alight_b_elite_100_10' (LightDatabase)
# Wall time: 9.02 ms
# Stored 'alight_w_elite_1000_10' (LightDatabase)
# Wall time: 28 ms
# Stored 'alight_b_elite_1000_10' (LightDatabase)
# Wall time: 40 ms
# Stored 'alight_w_elite_10000_10' (LightDatabase)
# Wall time: 178 ms
# Stored 'alight_b_elite_10000_10' (LightDatabase)
# Wall time: 202 ms
# -------enriched
# Stored 'alight_w_elite_1000_6_20000' (LightDatabase)
# Wall time: 17 ms
# Stored 'alight_b_elite_1000_6_20000' (LightDatabase)
# Wall time: 10.5 ms
# Stored 'alight_w_elite_1000_10_20000' (LightDatabase)
# Wall time: 28.2 ms
# Stored 'alight_b_elite_1000_10_20000' (LightDatabase)
# Wall time: 27 ms
# Stored 'alight_w_elite_10000_12_20000' (LightDatabase)
# Wall time: 294 ms
# ...

# %%
print("--------eco")
# %time a52light_w_c25_all_20.analyze(52)
# %time a52light_b_c25_all_20.analyze(52)

print("--------few elite")
# %time a52light_w_elite_100_10.analyze(52)
# %time a52light_b_elite_100_10.analyze(52)

# %time a52light_w_elite_1000_10.analyze(52)
# %time a52light_b_elite_1000_10.analyze(52)

# %time a52light_w_elite_10000_10.analyze(52)
# %time a52light_b_elite_10000_10.analyze(52)


print("-------enriched")

# %time a52light_w_elite_1000_6_20000.analyze(52)
# %time a52light_b_elite_1000_6_20000.analyze(52)

# %time a52light_w_elite_1000_10_20000.analyze(52)
# %time a52light_b_elite_1000_10_20000.analyze(52)

# %time a52light_w_elite_10000_12_20000.analyze(52)
# %time a52light_b_elite_10000_12_20000.analyze(52)

# %time a52light_w_elite_1000_10_300000.analyze(52)
# %time a52light_b_elite_1000_10_300000.analyze(52)

print("--------trim20")


# %time a52light_w_elite_1000_6_20000_t20.analyze(52)
# %time a52light_b_elite_1000_6_20000_t20.analyze(52)

# %time a52light_w_elite_1000_10_20000_t20.analyze(52)
# %time a52light_b_elite_1000_10_20000_t20.analyze(52)

# %time a52light_w_elite_10000_12_20000_t20.analyze(52)
# %time a52light_b_elite_10000_12_20000_t20.analyze(52)

# %time a52light_w_elite_1000_10_300000_t20.analyze(52)
# %time a52light_b_elite_1000_10_300000_t20.analyze(52)

print("--------trim100")

# %time a52light_w_elite_1000_6_20000_t100.analyze(52)
# %time a52light_b_elite_1000_6_20000_t100.analyze(52)

# %time a52light_w_elite_1000_10_20000_t100.analyze(52)
# %time a52light_b_elite_1000_10_20000_t100.analyze(52)

# %time a52light_w_elite_10000_12_20000_t100.analyze(52)
# %time a52light_b_elite_10000_12_20000_t100.analyze(52)

# %time a52light_w_elite_1000_10_300000_t100.analyze(52)
# %time a52light_b_elite_1000_10_300000_t100.analyze(52)
# Out:
# --------eco
# Wall time: 157 ms
# Wall time: 169 ms
# --------few elite
# Wall time: 13 ms
# Wall time: 11 ms
# Wall time: 65 ms
# Wall time: 82 ms
# Wall time: 529 ms
# Wall time: 2.07 s
# -------enriched
# Wall time: 12 ms
# Wall time: 19 ms
# Wall time: 60 ms
# Wall time: 56 ms
# Wall time: 523 ms
# Wall time: 675 ms
# Wall time: 103 ms
# Wall time: 89.9 ms
# --------trim20
# Wall time: 6.99 ms
# Wall time: 12 ms
# Wall time: 12 ms
# Wall time: 17 ms
# Wall time: 28 ms
# Wall time: 25 ms
# Wall time: 31 ms
# Wall time: 32 ms
# --------trim100
# Wall time: 996 µs
# Wall time: 998 µs
# Wall time: 2 ms
# Wall time: 2 ms
# Wall time: 4 ms
# Wall time: 3 ms
# Wall time: 15 ms
# Wall time: 15 ms

# %%
print("--------eco")
# %time %store a52light_w_c25_all_20
# %time %store a52light_b_c25_all_20

print("--------few elite")
# %time %store a52light_w_elite_100_10
# %time %store a52light_b_elite_100_10

# %time %store a52light_w_elite_1000_10
# %time %store a52light_b_elite_1000_10

# %time %store a52light_w_elite_10000_10
# %time %store a52light_b_elite_10000_10


print("-------enriched")

# %time %store a52light_w_elite_1000_6_20000
# %time %store a52light_b_elite_1000_6_20000

# %time %store a52light_w_elite_1000_10_20000
# %time %store a52light_b_elite_1000_10_20000

# %time %store a52light_w_elite_10000_12_20000
# %time %store a52light_b_elite_10000_12_20000

# %time %store a52light_w_elite_1000_10_300000
# %time %store a52light_b_elite_1000_10_300000

print("--------trim20")


# %time %store a52light_w_elite_1000_6_20000_t20
# %time %store a52light_b_elite_1000_6_20000_t20

# %time %store a52light_w_elite_1000_10_20000_t20
# %time %store a52light_b_elite_1000_10_20000_t20

# %time %store a52light_w_elite_10000_12_20000_t20
# %time %store a52light_b_elite_10000_12_20000_t20

# %time %store a52light_w_elite_1000_10_300000_t20
# %time %store a52light_b_elite_1000_10_300000_t20

print("--------trim100")

# %time %store a52light_w_elite_1000_6_20000_t100
# %time %store a52light_b_elite_1000_6_20000_t100

# %time %store a52light_w_elite_1000_10_20000_t100
# %time %store a52light_b_elite_1000_10_20000_t100

# %time %store a52light_w_elite_10000_12_20000_t100
# %time %store a52light_b_elite_10000_12_20000_t100

# %time %store a52light_w_elite_1000_10_300000_t100
# %time %store a52light_b_elite_1000_10_300000_t100
# Out:
# --------eco
# Stored 'a52light_w_c25_all_20' (LightDatabase)
# Wall time: 69 ms
# Stored 'a52light_b_c25_all_20' (LightDatabase)
# Wall time: 68 ms
# --------few elite
# Stored 'a52light_w_elite_100_10' (LightDatabase)
# Wall time: 5.99 ms
# Stored 'a52light_b_elite_100_10' (LightDatabase)
# Wall time: 7 ms
# Stored 'a52light_w_elite_1000_10' (LightDatabase)
# Wall time: 27 ms
# Stored 'a52light_b_elite_1000_10' (LightDatabase)
# Wall time: 35 ms
# Stored 'a52light_w_elite_10000_10' (LightDatabase)
# Wall time: 192 ms
# Stored 'a52light_b_elite_10000_10' (LightDatabase)
# Wall time: 201 ms
# -------enriched
# Stored 'a52light_w_elite_1000_6_20000' (LightDatabase)
# Wall time: 11 ms
# Stored 'a52light_b_elite_1000_6_20000' (LightDatabase)
# Wall time: 10.7 ms
# Stored 'a52light_w_elite_1000_10_20000' (LightDatabase)
# Wall time: 28 ms
# Stored 'a52light_b_elite_1000_10_20000' (LightDatabase)
# Wall time: 26 ms
# Stored 'a52light_w_elite_10000_12_20000' (LightDatabase)
# ...

# %%
print("--------eco")
# %time a365light_w_c25_all_20.analyze(365)
# %time a365light_b_c25_all_20.analyze(365)

print("--------few elite")
# %time a365light_w_elite_100_10.analyze(365)
# %time a365light_b_elite_100_10.analyze(365)

# %time a365light_w_elite_1000_10.analyze(365)
# %time a365light_b_elite_1000_10.analyze(365)

# %time a365light_w_elite_10000_10.analyze(365)
# %time a365light_b_elite_10000_10.analyze(365)


print("-------enriched")

# %time a365light_w_elite_1000_6_20000.analyze(365)
# %time a365light_b_elite_1000_6_20000.analyze(365)

# %time a365light_w_elite_1000_10_20000.analyze(365)
# %time a365light_b_elite_1000_10_20000.analyze(365)

# %time a365light_w_elite_10000_12_20000.analyze(365)
# %time a365light_b_elite_10000_12_20000.analyze(365)

# %time a365light_w_elite_1000_10_300000.analyze(365)
# %time a365light_b_elite_1000_10_300000.analyze(365)

print("--------trim20")


# %time a365light_w_elite_1000_6_20000_t20.analyze(365)
# %time a365light_b_elite_1000_6_20000_t20.analyze(365)

# %time a365light_w_elite_1000_10_20000_t20.analyze(365)
# %time a365light_b_elite_1000_10_20000_t20.analyze(365)

# %time a365light_w_elite_10000_12_20000_t20.analyze(365)
# %time a365light_b_elite_10000_12_20000_t20.analyze(365)

# %time a365light_w_elite_1000_10_300000_t20.analyze(365)
# %time a365light_b_elite_1000_10_300000_t20.analyze(365)

print("--------trim100")

# %time a365light_w_elite_1000_6_20000_t100.analyze(365)
# %time a365light_b_elite_1000_6_20000_t100.analyze(365)

# %time a365light_w_elite_1000_10_20000_t100.analyze(365)
# %time a365light_b_elite_1000_10_20000_t100.analyze(365)

# %time a365light_w_elite_10000_12_20000_t100.analyze(365)
# %time a365light_b_elite_10000_12_20000_t100.analyze(365)

# %time a365light_w_elite_1000_10_300000_t100.analyze(365)
# %time a365light_b_elite_1000_10_300000_t100.analyze(365)
# Out:
# --------eco
# Wall time: 271 ms
# Wall time: 270 ms
# --------few elite
# Wall time: 6.99 ms
# Wall time: 9.01 ms
# Wall time: 62 ms
# Wall time: 74.9 ms
# Wall time: 525 ms
# Wall time: 624 ms
# -------enriched
# Wall time: 14 ms
# Wall time: 20 ms
# Wall time: 79 ms
# Wall time: 70 ms
# Wall time: 828 ms
# Wall time: 1.39 s
# Wall time: 87 ms
# Wall time: 77.9 ms
# --------trim20
# Wall time: 9.99 ms
# Wall time: 6 ms
# Wall time: 9.99 ms
# Wall time: 11 ms
# Wall time: 27 ms
# Wall time: 29 ms
# Wall time: 44 ms
# Wall time: 37 ms
# --------trim100
# Wall time: 999 µs
# Wall time: 2 ms
# Wall time: 2 ms
# Wall time: 2 ms
# Wall time: 4 ms
# Wall time: 4 ms
# Wall time: 18 ms
# Wall time: 20 ms

# %%
print("--------eco")
# %time %store a365light_w_c25_all_20
# %time %store a365light_b_c25_all_20

print("--------few elite")
# %time %store a365light_w_elite_100_10
# %time %store a365light_b_elite_100_10

# %time %store a365light_w_elite_1000_10
# %time %store a365light_b_elite_1000_10

# %time %store a365light_w_elite_10000_10
# %time %store a365light_b_elite_10000_10


print("-------enriched")

# %time %store a365light_w_elite_1000_6_20000
# %time %store a365light_b_elite_1000_6_20000

# %time %store a365light_w_elite_1000_10_20000
# %time %store a365light_b_elite_1000_10_20000

# %time %store a365light_w_elite_10000_12_20000
# %time %store a365light_b_elite_10000_12_20000

# %time %store a365light_w_elite_1000_10_300000
# %time %store a365light_b_elite_1000_10_300000

print("--------trim20")


# %time %store a365light_w_elite_1000_6_20000_t20
# %time %store a365light_b_elite_1000_6_20000_t20

# %time %store a365light_w_elite_1000_10_20000_t20
# %time %store a365light_b_elite_1000_10_20000_t20

# %time %store a365light_w_elite_10000_12_20000_t20
# %time %store a365light_b_elite_10000_12_20000_t20

# %time %store a365light_w_elite_1000_10_300000_t20
# %time %store a365light_b_elite_1000_10_300000_t20

print("--------trim100")

# %time %store a365light_w_elite_1000_6_20000_t100
# %time %store a365light_b_elite_1000_6_20000_t100

# %time %store a365light_w_elite_1000_10_20000_t100
# %time %store a365light_b_elite_1000_10_20000_t100

# %time %store a365light_w_elite_10000_12_20000_t100
# %time %store a365light_b_elite_10000_12_20000_t100

# %time %store a365light_w_elite_1000_10_300000_t100
# %time %store a365light_b_elite_1000_10_300000_t100
# Out:
# --------eco
# Stored 'a365light_w_c25_all_20' (LightDatabase)
# Wall time: 75.5 ms
# Stored 'a365light_b_c25_all_20' (LightDatabase)
# Wall time: 98 ms
# --------few elite
# Stored 'a365light_w_elite_100_10' (LightDatabase)
# Wall time: 5.98 ms
# Stored 'a365light_b_elite_100_10' (LightDatabase)
# Wall time: 5.02 ms
# Stored 'a365light_w_elite_1000_10' (LightDatabase)
# Wall time: 41 ms
# Stored 'a365light_b_elite_1000_10' (LightDatabase)
# Wall time: 29 ms
# Stored 'a365light_w_elite_10000_10' (LightDatabase)
# Wall time: 177 ms
# Stored 'a365light_b_elite_10000_10' (LightDatabase)
# Wall time: 214 ms
# -------enriched
# Stored 'a365light_w_elite_1000_6_20000' (LightDatabase)
# Wall time: 10.4 ms
# Stored 'a365light_b_elite_1000_6_20000' (LightDatabase)
# Wall time: 10 ms
# Stored 'a365light_w_elite_1000_10_20000' (LightDatabase)
# Wall time: 27 ms
# Stored 'a365light_b_elite_1000_10_20000' (LightDatabase)
# Wall time: 37 ms
# ...

# %% [markdown]
# ## tests

# %%
data = a365light_b_elite_10000_12_20000_t20

# %%
first = data.all_positions[0]

# %%
first.defence_strategy
# Out:
# {0: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 0, 3: 0, 2: 0, 1: 0, 0: 0},
#  1: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 0, 3: 0, 2: 0, 1: 1, 0: 0},
#  2: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 0, 3: 0, 2: 2, 1: 0, 0: 0},
#  3: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 0, 3: 0, 2: 2, 1: 1, 0: 0},
#  4: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 0, 3: 0, 2: 3, 1: 1, 0: 0},
#  5: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 0, 3: 0, 2: 2, 1: 3, 0: 0},
#  6: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 0, 3: 0, 2: 3, 1: 3, 0: 0},
#  7: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 1, 3: 0, 2: 3, 1: 3, 0: 0},
#  8: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 1, 3: 0, 2: 4, 1: 3, 0: 0},
#  9: {11: 0, 10: 0, 9: 0, 8: 0, 7: 0, 6: 0, 5: 0, 4: 1, 3: 0, 2: 5, 1: 3, 0: 0},
#  10: {11: 0,
#   10: 0,
#   9: 0,
#   8: 0,
#   7: 0,
#   6: 0,
#   5: 0,
#   4: 1,
#   3: 0,
#   2: 5,
#   1: 4,
#   0: 0},
#  11: {11: 0,
#   10: 0,
#   9: 0,
#   8: 0,
# ...

# %%
first.student_advantage
# Out:
# {0: 0.04250492109565276,
#  1: 0.225,
#  2: 0.13888144018466322,
#  3: 0.1622065214162894,
#  4: 0.1810496065325436,
#  5: 0.20437468776416978,
#  6: 0.2181015712482263,
#  7: 0.2324098711282421,
#  8: 0.24169296360644985,
#  9: 0.24930136170687953,
#  10: 0.2518262235076194,
#  11: 0.2553807054905489,
#  12: 0.2593017509388425,
#  13: 0.26182661273958235,
#  14: 0.2653810947225119,
#  15: 0.26803900641880374,
#  16: 0.2705638682195436,
#  17: 0.2725695873844768,
#  18: 0.2749079496546224,
#  19: 0.2769136688195556,
#  20: 0.27847582299900414,
#  21: 0.28048154216393734,
#  22: 0.281250509526706,
#  23: 0.2831430372152209,
#  24: 0.28391200457798954,
#  25: 0.28456788162091917,
#  26: 0.28533684898368783,
#  27: 0.28554497349175717,
#  28: 0.28569184280257814,
#  29: 0.28560463879787584,
#  30: 0.28568602920226466,
#  31: 0.2855833468003404,
#  32: 0.2854541214786159,
#  33: 0.28545898252485097,
#  34: 0.28535630012292673,
#  35: 0.2850719488560596,
#  36: 0.28466989780071106,
# ...

# %%
data.positions_by_ply[1]
# Out:
# {1: <lightdb.LightDefencePosition at 0x2c961c0fb50>,
#  7: <lightdb.LightDefencePosition at 0x2c961c1d100>,
#  13: <lightdb.LightDefencePosition at 0x2c961c1dcd0>,
#  101: <lightdb.LightDefencePosition at 0x2c962207640>,
#  119: <lightdb.LightDefencePosition at 0x2c962207a90>,
#  138: <lightdb.LightDefencePosition at 0x2c962207e80>,
#  189: <lightdb.LightDefencePosition at 0x2c9622259d0>,
#  384: <lightdb.LightDefencePosition at 0x2c96227b460>,
#  790: <lightdb.LightDefencePosition at 0x2c96231c1f0>,
#  915: <lightdb.LightDefencePosition at 0x2c962337e80>,
#  1091: <lightdb.LightDefencePosition at 0x2c962383700>,
#  1470: <lightdb.LightDefencePosition at 0x2c962405eb0>,
#  1531: <lightdb.LightDefencePosition at 0x2c96241ed30>,
#  1979: <lightdb.LightDefencePosition at 0x2c9624d42e0>,
#  2143: <lightdb.LightDefencePosition at 0x2c962507940>,
#  2319: <lightdb.LightDefencePosition at 0x2c962554190>,
#  2406: <lightdb.LightDefencePosition at 0x2c96256e5b0>,
# ...

# %%
# Out:
# {5: <lightdb.LightDefencePosition at 0x12ccd11d190>,
#  11: <lightdb.LightDefencePosition at 0x12ccd11d970>,
#  17: <lightdb.LightDefencePosition at 0x12ccd11d790>,
#  22: <lightdb.LightDefencePosition at 0x12ccd34d400>,
#  27: <lightdb.LightDefencePosition at 0x12ccd34d5b0>,
#  30: <lightdb.LightDefencePosition at 0x12ccd34d640>,
#  35: <lightdb.LightDefencePosition at 0x12ccd34d730>,
#  40: <lightdb.LightDefencePosition at 0x12ccd34d820>,
#  45: <lightdb.LightDefencePosition at 0x12ccd34d910>,
#  50: <lightdb.LightDefencePosition at 0x12ccd34da30>,
#  55: <lightdb.LightDefencePosition at 0x12ccd34db20>,
#  57: <lightdb.LightDefencePosition at 0x12ccd34d460>,
#  62: <lightdb.LightDefencePosition at 0x12ccd34dc70>,
#  66: <lightdb.LightDefencePosition at 0x12ccd10a910>,
#  71: <lightdb.LightDefencePosition at 0x12ccd34ddf0>,
#  75: <lightdb.LightDefencePosition at 0x12ccd34de80>,
#  79: <lightdb.LightDefencePosition at 0x12ccd34df40>,
# ...
